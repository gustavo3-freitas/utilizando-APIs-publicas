# %% [markdown]
# # Lendo APIs

# %% [markdown]
# A base utilizada são dados públicos do governo e foram obtidos públicos através de uma API (*Application Programming Interface*).
#
# Baixou-se os dados de PVL (Pedidos de Verificação de Limites) realizados por diversos estados

# %%
#atribuindo link
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'

# %%
r = requests.get(url)

# %%
#verificando status
r.status_code
# Out:
# 200

# %%
#obtendo dados json
data_json = r.json()

# %%
print(data_json['items'])
# Out:
# [{'id_pleito': 44136, 'tipo_interessado': 'Município', 'interessado': 'Nova Tebas', 'cod_ibge': 4117271, 'uf': 'PR', 'num_pvl': 'PVL02.000428/2021-75', 'status': 'Deferido (PVL-IF)', 'num_processo': None, 'data_protocolo': None, 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Aquisição de terrenos, imóveis e/ou construção de instalações', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Agência de Fomento do Paraná S/A', 'moeda': 'Real', 'valor': 603034, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 1, 'data_status': '05/08/2021'}, {'id_pleito': 44842, 'tipo_interessado': 'Município', 'interessado': 'Campinas do Sul', 'cod_ibge': 4303806, 'uf': 'RS', 'num_pvl': 'PVL02.001072/2021-97', 'status': 'Deferido (PVL-IF)', 'num_processo': None, 'data_protocolo': None, 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Aquisição de máquinas, equipamentos e veículos', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco do Brasil S/A', 'mo
# ...

# %%
#criando data frame
df = pd.DataFrame(data_json['items'])

df
# Out:
#       id_pleito tipo_interessado          interessado  cod_ibge  uf  \
# 0         44136        Município           Nova Tebas   4117271  PR
# 1         44842        Município      Campinas do Sul   4303806  RS
# 2         41265        Município         Nova Olímpia   5106232  MT
# 3         41428        Município             Pedreira   3537107  SP
# 4         42479        Município  Boa Vista do Buricá   4302204  RS
# ...         ...              ...                  ...       ...  ..
# 4995      58230        Município                Uchoa   3555604  SP
# 4996      53473        Município         Borrazópolis   4103305  PR
# 4997      64895        Município                Tibau   2411056  RN
# 4998      61696        Município              Mormaço   4312427  RS
# 4999      48151        Município       Venâncio Aires   4322608  RS
#
#                    num_pvl             status          num_processo  \
# 0     PVL02.000428/2021-75  Deferido (PVL-IF)                  None
# ...

# %%
#obtendo PVLs realizados por municípios no estado do Rio de Janeiro

df_rj = df[df['uf'] == 'RJ']

df_rj
# Out:
#       id_pleito tipo_interessado             interessado  cod_ibge  uf  \
# 33         6833           Estado          Rio de Janeiro        33  RJ
# 135        5914        Município               Nilópolis   3303203  RJ
# 151       65407        Município                Itaboraí   3301900  RJ
# 265        6644        Município      São João de Meriti   3305109  RJ
# 278       11707        Município      São João de Meriti   3305109  RJ
# ...         ...              ...                     ...       ...  ..
# 4525      12093        Município                 Resende   3304201  RJ
# 4596       9750           Estado          Rio de Janeiro        33  RJ
# 4759      13784        Município  Santo Antônio de Pádua   3304706  RJ
# 4975      31378        Município              Petrópolis   3303906  RJ
# 4993      66452        Município          Barra do Piraí   3300308  RJ
#
#                    num_pvl                          status  \
# ...

# %%
#Obtendo os três status mais frequentes da base e suas respectivas frequências são:

# - Deferido (24), - Encaminhado à PGFN com manifestação técnica favorável (14), - Arquivado (12)
df_rj.status.explode().value_counts()
# Out:
# status
# Deferido                                                 24
# Encaminhado à PGFN com manifestação técnica favorável    14
# Arquivado                                                12
# Regularizado                                              6
# Arquivado por decurso de prazo                            5
# Deferido (PVL-IF)                                         3
# Arquivado a pedido                                        2
# Em análise                                                2
# Name: count, dtype: int64

# %%
#Adicionando uma nova variável que contenha o ano do status. Observe que data_status vem como tipo object no DataFrame. Dica: você pode usar o método .str para transformar o tipo da variável em string, em seguida um método como slice() ou split().

df_rj.loc['ano_status'] = df_rj['data_status'].str.slice(-4)

df_rj['ano_status'].value_counts()
# Out:
# ano_status
# 2008    11
# 2023     6
# 2014     6
# 2007     6
# 2011     6
# 2013     5
# 2009     4
# 2019     4
# 2016     3
# 2012     3
# 2010     2
# 2015     2
# 2020     2
# 2024     2
# 2018     1
# 2004     1
# 2022     1
# 2017     1
# 2006     1
# 2003     1
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
# Função que recebe como argumento o UF da consulta e o tipo de interessado
def consulta_pvl(uf, tipo_interessado):
    base_url = f"http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl"
    params = {
        'uf': uf,
        'tipo_interessado': tipo_interessado
    }

    try:
        response = requests.get(base_url, params=params)
        data = response.json()
        df = pd.DataFrame(data['items'])
        return df
    except requests.exceptions.RequestException as e:
        print(f"Erro na consulta da API: {e}")
        return pd.DataFrame()  # Retorna um DataFrame vazio em caso de erro

# %%
# Consultar solicitações para o Estado de Minas Gerais com status 'Arquivado por decurso de prazo'
df_mg_estado = consulta_pvl('MG', 'Estado')

arquivadas_mg = df_mg_estado[df_mg_estado['status'] == 'Arquivado por decurso de prazo']

#obtendo número de solicitações arquivadas por decurso de prazo
num_solicitacoes_arquivadas_mg = len(solicitacoes_arquivadas_mg)
num_solicitacoes_arquivadas_mg
# Out:
# 1

# %%
#Qual é o município da Bahia com mais solicitações deferidas é "Camaçari, com 20.

df_ba_municipio = consulta_pvl('BA', 'Município')

ba_municipio_deferidas = df_ba_municipio['interessado'].value_counts() 
ba_municipio_deferidas
# Out:
# interessado
# Camaçari                   20
# Luís Eduardo Magalhães     19
# Salvador                   19
# Vitória da Conquista       16
# Amargosa                   16
#                            ..
# Crisópolis                  1
# Ponto Novo                  1
# Ibicoara                    1
# Cabaceiras do Paraguaçu     1
# Piatã                       1
# Name: count, Length: 301, dtype: int64

# %%
df_ba_estado = consulta_pvl('BA', 'Estado')

df_ba_estado.to_csv('solicitacoes_bahia_estado.csv', index=False)
#Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'
